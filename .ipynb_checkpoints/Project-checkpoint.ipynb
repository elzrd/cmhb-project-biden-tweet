# %% [markdown]
# # A Candidate's tweets during the pandemic
#
# ### Computational Models of Human Behavior Project
#
# ##### Zordan Elena
# _M.Sc. Data Science, University of Trento_

# %% [markdown]
# ---------------------------------------
# ### Libraries

# %%
import pandas as pd
import numpy as np 
import sys
import nltk
import string
import datetime
import seaborn as sns
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
from nrclex import NRCLex
from PIL import Image 
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords, wordnet
from nltk.sentiment.vader import SentimentIntensityAnalyzer 
from nltk import tokenize, sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer, SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

# %% [markdown]
# # 1) Exploratory Data Analysis
#
# Some initial EDA in order to see how did the consensus and twitter activites of Joe Biden change over the years.

# %%
joe = pd.read_csv("/Users/elenazordan/Desktop/corsi ds/CMHB/project_ALL/project/data/JoeBidenTweets.csv")

# %%
joe.shape
# Out:
# (6064, 8)

# %% [markdown]
# 6064 rows X 8 columns

# %% [markdown]
# Visualize the number of likes, retweets and replies per day

# %%
joe['timestamp'] = joe['timestamp'].apply(lambda x : datetime.datetime.strptime(x.split(" ")[0], "%Y-%m-%d"))
joe.head()
# Out:
#                    id  timestamp  \
# 0           361388562 2007-10-24
# 1           543984392 2007-12-29
# 2  189287227321356289 2012-04-09
# 3  189287350034104320 2012-04-09
# 4  189339650610036736 2012-04-09
#
#                                                  url  \
# 0      https://twitter.com/JoeBiden/status/361388562
# 1      https://twitter.com/JoeBiden/status/543984392
# 2  https://twitter.com/JoeBiden/status/1892872273...
# 3  https://twitter.com/JoeBiden/status/1892873500...
# 4  https://twitter.com/JoeBiden/status/1893396506...
#
#                                                tweet  replies  retweets  \
# 0  Tune in 11:30 ET tomorrow for a live webcast o...       19         5
# 1  Iowans, there's a good chance there's a Biden ...       13        16
# 2  We're excited to announce that @JoeBiden is be...       21        82
# 3  Campaign staff will run this account to keep y...      144        76
# 4  News for you this morning: VP Biden will speak...       10        54
#
# ...

# %%
joe_count = pd.DataFrame()

joe_count['replies'] = joe.groupby(['timestamp'])['replies'].sum()
joe_count['retweets'] = joe.groupby(['timestamp'])['retweets'].sum()
joe_count['quotes'] = joe.groupby(['timestamp'])['quotes'].sum()
joe_count['likes'] = joe.groupby(['timestamp'])['likes'].sum()
joe_final = joe_count.reset_index()
joe_final = joe_final.iloc[2:]
joe_final
# Out:
#       timestamp  replies  retweets  quotes    likes
# 2    2012-04-09      318       764      38      145
# 3    2012-04-10       71       308       1      152
# 4    2012-04-11       79       555       0      233
# 5    2012-04-12       43       143       0       29
# 6    2012-04-13      197       466       0      107
# ...         ...      ...       ...     ...      ...
# 1081 2020-10-28   100590    207993   27088  1648256
# 1082 2020-10-29    95494    188689   27346  1412505
# 1083 2020-10-30    87215    206124   31551  1583683
# 1084 2020-10-31   105542    262108   39577  2058368
# 1085 2020-11-01    51603    104304   12245   702887
#
# [1084 rows x 5 columns]

# %% [markdown]
# **Plot with seaborn**

# %%
f, axs = plt.subplots(1, 2, figsize=(13, 7), gridspec_kw=dict(width_ratios=[4, 4]))


sns.scatterplot(data=joe_final, x="timestamp", y="likes",alpha=.9, color="darkred",ax=axs[0])
sns.scatterplot(data=joe_final, x="timestamp", y="retweets",alpha=.9, color="darkgreen", ax=axs[0])
sns.scatterplot(data=joe_final, x="timestamp", y="replies",alpha=.5, color="lightblue",ax=axs[0])

axs[0].set_xlabel('')
axs[0].set_ylabel('')    

sns.lineplot(data=joe_final, x="timestamp", y="likes",alpha=.8, color="darkred", ax=axs[1]) #shrink=.8
sns.lineplot(data=joe_final, x="timestamp", y="retweets",alpha=.8, color="darkgreen", ax=axs[1])
sns.lineplot(data=joe_final, x="timestamp", y="replies",alpha=.8,color="lightblue", ax=axs[1])

axs[1].set_xlabel('')
axs[1].set_ylabel('')


f.text(0.5, 0, 'Year', ha='center')
f.text(0, 0.5, 'Frequence', va='center', rotation='vertical')

f.tight_layout()

f.subplots_adjust(top=0.9)
f.suptitle("Number of likes, retweets and replies over the years 2012-2020", fontsize='large')

f.legend(labels=['Likes', 'Retweets', 'Replies'], loc='upper right', frameon=True, fontsize='small')
plt.show()

# %% [markdown]
# Better visualise the last year (from December 2019 to November 2020)

# %%
joe_final_2020 = joe_final.iloc[747:]
joe_final_2020.head()
# Out:
#      timestamp  replies  retweets  quotes   likes
# 749 2019-12-01     5683      9199     954   65427
# 750 2019-12-02     3773      3546     560   19882
# 751 2019-12-03     5496      8158     942   70231
# 752 2019-12-04     2030      1975     272   10212
# 753 2019-12-05    46527     76499   20594  294290

# %%
f, axs = plt.subplots(1, 2, figsize=(13, 7), gridspec_kw=dict(width_ratios=[3, 3]))


sns.scatterplot(data=joe_final_2020, x="timestamp", y="likes",alpha=.9, color="darkred",ax=axs[0])
sns.scatterplot(data=joe_final_2020, x="timestamp", y="retweets",alpha=.9, color="darkgreen", ax=axs[0])
sns.scatterplot(data=joe_final_2020, x="timestamp", y="replies",alpha=.5, color="lightblue",ax=axs[0])

axs[0].set_xlabel('')
axs[0].set_ylabel('')    

sns.lineplot(data=joe_final_2020, x="timestamp", y="likes",alpha=.8, color="darkred", ax=axs[1]) #shrink=.8
sns.lineplot(data=joe_final_2020, x="timestamp", y="retweets",alpha=.8, color="darkgreen", ax=axs[1])
sns.lineplot(data=joe_final_2020, x="timestamp", y="replies",alpha=.8,color="lightblue", ax=axs[1])

axs[1].set_xlabel('')
axs[1].set_ylabel('')


f.text(0.5, 0, 'Date', ha='center')
f.text(0, 0.5, 'Frequence', va='center', rotation='vertical')

f.tight_layout()

f.subplots_adjust(top=0.9)
f.suptitle("Number of likes, retweets and replies from December 2019", fontsize='large')

f.legend(labels=['Likes', 'Retweets', 'Replies'], loc='upper right', frameon=True, fontsize='small')
plt.show()

# %% [markdown]
# As we can see, the number of likes increased exponentially over 2020, in particular since May 2020.
# Also the number of retweets increased, even though much less, but its trend is consistent with the ones of the likes.
# With respect to the number of replies, there was a small growth from September 2020 onward.
# Number of quotes was not included since it reached quite low values.

# %% [markdown]
# ---------------------------------------
#
# Code used to find out the **most liked** and **retweeted** tweets of Joe Biden.
# The findings were added to the project proposal presentation

# %%
most_liked_tweet = joe[joe.likes==max(joe.likes)]
most_retweet_tweet = joe[joe.retweets==max(joe.retweets)]

# %% [markdown]
# **Most liked tweet** (1,890,946 likes)
#
# "Donald Trump is the worst president we've ever had"
#
#
# **Most retweeted tweet** (326,070 rt)
#
# "I can't believe I have to say this, but please don't drink bleach"

# %% [markdown]
# ---------------------------------------
#
# # 2) Text preprocessing with NLTK
#
# Select tweets created from December 2019 onward and create a new dataframe (df).

# %%
df = joe[joe.timestamp >= '2019-12-01'].reset_index(drop=True)

# %%
df
# Out:
#                        id  timestamp  \
# 0     1200932522177122304 2019-12-01
# 1     1201226459278385154 2019-12-01
# 2     1201255903498002432 2019-12-01
# 3     1201296419987972096 2019-12-02
# 4     1201303718391615493 2019-12-02
# ...                   ...        ...
# 3121  1322865972819251200 2020-11-01
# 3122  1322871257902145536 2020-11-01
# 3123  1322876039144636417 2020-11-01
# 3124  1322881072363917312 2020-11-01
# 3125  1322886357535150081 2020-11-01
#
#                                                     url  \
# 0     https://twitter.com/JoeBiden/status/1200932522...
# 1     https://twitter.com/JoeBiden/status/1201226459...
# 2     https://twitter.com/JoeBiden/status/1201255903...
# 3     https://twitter.com/JoeBiden/status/1201296419...
# 4     https://twitter.com/JoeBiden/status/1201303718...
# ...                                                 ...
# 3121  https://twitter.com/JoeBiden/status/1322865972...
# 3122  https://twitter.com/JoeBiden/status/1322871257...
# ...

# %%
#UNCOMMENT if needed: just once (the first time) in order to download all 

#nltk.download()

# %% [markdown]
# ### Tokenization

# %%
df['tokenized'] = df['tweet'].apply(nltk.tokenize.WhitespaceTokenizer().tokenize)
df.head()
# Out:
#                     id  timestamp  \
# 0  1200932522177122304 2019-12-01
# 1  1201226459278385154 2019-12-01
# 2  1201255903498002432 2019-12-01
# 3  1201296419987972096 2019-12-02
# 4  1201303718391615493 2019-12-02
#
#                                                  url  \
# 0  https://twitter.com/JoeBiden/status/1200932522...
# 1  https://twitter.com/JoeBiden/status/1201226459...
# 2  https://twitter.com/JoeBiden/status/1201255903...
# 3  https://twitter.com/JoeBiden/status/1201296419...
# 4  https://twitter.com/JoeBiden/status/1201303718...
#
#                                                tweet  replies  retweets  \
# 0  Eight years of Donald Trump will fundamentally...     4408      7287
# 1  Over the last 30 years, the fight against #HIV...      176       512
# 2  Every voter counts. We need a president who is...     1099      1400
# 3  Congressman and former Admiral @JoeSestak has ...      111       250
# ...

# %%
df['tokenized'][0][:10] #shows only the first 10 elements of the first tweet
# Out:
# ['Eight',
#  'years',
#  'of',
#  'Donald',
#  'Trump',
#  'will',
#  'fundamentally',
#  'alter',
#  'the',
#  'character']

# %% [markdown]
# ### Stopwords removal

# %%
stop_words = set(stopwords.words('english'))
df['stopwords_removed'] = df['tokenized'].apply(lambda x: [word for word in x if word.lower() not in stop_words])
df.head()
# Out:
#                     id  timestamp  \
# 0  1200932522177122304 2019-12-01
# 1  1201226459278385154 2019-12-01
# 2  1201255903498002432 2019-12-01
# 3  1201296419987972096 2019-12-02
# 4  1201303718391615493 2019-12-02
#
#                                                  url  \
# 0  https://twitter.com/JoeBiden/status/1200932522...
# 1  https://twitter.com/JoeBiden/status/1201226459...
# 2  https://twitter.com/JoeBiden/status/1201255903...
# 3  https://twitter.com/JoeBiden/status/1201296419...
# 4  https://twitter.com/JoeBiden/status/1201303718...
#
#                                                tweet  replies  retweets  \
# 0  Eight years of Donald Trump will fundamentally...     4408      7287
# 1  Over the last 30 years, the fight against #HIV...      176       512
# 2  Every voter counts. We need a president who is...     1099      1400
# 3  Congressman and former Admiral @JoeSestak has ...      111       250
# ...

# %%
#create a string column containing texts
df['text_string'] = df['stopwords_removed'].apply(lambda x: ' '.join(x))

df['text_string'][4]
# Out:
# 'We’re officially road eight-day #NoMalarkey Tour across Iowa! https://t.co/cGSblBnHoZ'

# %% [markdown]
# ##### Removal of rare words and other characters

# %%
count = Counter()

# %%
remove = ['—','––','-', 'https']

def del_remove(text):
    """
    function to remove some words and characters
    """
    return " ".join([word for word in str(text).split() if word not in remove and not word.startswith('https')])



df['text_string'] = df['text_string'].apply(lambda x: del_remove(x))

# %%
rare_word = 5

Rarewords = set([i for (i, ic) in count.most_common()[:-rare_word:-1]])

def del_rarewords(text):
    """
    function to remove the rare words
    """
    return " ".join([word for word in str(text).split() if word not in Rarewords])



df['text_string'] = df['text_string'].apply(lambda x: del_rarewords(x))

# %% [markdown]
# ##### Most frequent words

# %%
# most frequent words


for text in df['text_string'].values:
    for word in text.split():
        count[word] = count[word] + 1


        
count.most_common(15)
# Out:
# [('Trump', 667),
#  ('Donald', 617),
#  ('need', 405),
#  ('get', 317),
#  ('American', 316),
#  ('make', 280),
#  ('us', 259),
#  ('President', 258),
#  ('one', 257),
#  ('president', 241),
#  ('people', 237),
#  ('every', 223),
#  ('time', 191),
#  ('nation', 188),
#  ('country', 185)]

# %% [markdown]
# ### Token Normalization
#
# This operation reduces words to base form to be analyzed as a single term.
#
#    * Stemming: A process of removing and replacing suffixes to get to the root form of the word, which is called stem.
#    * Lemmatization: returns the base or dictionary form of a word.

# %% [markdown]
# ##### Stemming
#
# Comparison between Porter's and Snowball's stemming algorithms.

# %%
words  = nltk.tokenize.WhitespaceTokenizer().tokenize(df["tweet"][100])
prova = pd.DataFrame()
prova['OriginalWords'] = pd.Series(words)
#porter's stemmer
porterStemmedWords = [nltk.stem.PorterStemmer().stem(word) for word in words]
prova['PorterStemmedWords'] = pd.Series(porterStemmedWords)
#SnowBall stemmer
snowballStemmedWords = [nltk.stem.SnowballStemmer("english").stem(word) for word in words]
prova['SnowballStemmedWords'] = pd.Series(snowballStemmedWords)
prova.head()
# Out:
#     OriginalWords PorterStemmedWords SnowballStemmedWords
# 0             The                the                  the
# 1           Trump              trump                trump
# 2  Administration          administr            administr
# 3              is                 is                   is
# 4      recklessly         recklessli             reckless

# %%
ps = PorterStemmer()
df['stemmed'] = df['text_string'].apply(lambda x: ps.stem(x)) 

df.head()
# Out:
#                     id  timestamp  \
# 0  1200932522177122304 2019-12-01
# 1  1201226459278385154 2019-12-01
# 2  1201255903498002432 2019-12-01
# 3  1201296419987972096 2019-12-02
# 4  1201303718391615493 2019-12-02
#
#                                                  url  \
# 0  https://twitter.com/JoeBiden/status/1200932522...
# 1  https://twitter.com/JoeBiden/status/1201226459...
# 2  https://twitter.com/JoeBiden/status/1201255903...
# 3  https://twitter.com/JoeBiden/status/1201296419...
# 4  https://twitter.com/JoeBiden/status/1201303718...
#
#                                                tweet  replies  retweets  \
# 0  Eight years of Donald Trump will fundamentally...     4408      7287
# 1  Over the last 30 years, the fight against #HIV...      176       512
# 2  Every voter counts. We need a president who is...     1099      1400
# 3  Congressman and former Admiral @JoeSestak has ...      111       250
# ...

# %% [markdown]
# #### Lemmatization
# Turn the words to base form

# %%
lemmatizer = WordNetLemmatizer()
wordnet_m = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}


def lemmat_pos_word(text):
    
    pos_tagger_text = nltk.pos_tag(text.split())
    
    return " ".join([lemmatizer.lemmatize(word, wordnet_m.get(pos[0],wordnet.NOUN)) for word,pos in pos_tagger_text])



df['lemmatization'] = df['text_string'].apply(lambda T : lemmat_pos_word(T))

df.head()
# Out:
#                     id  timestamp  \
# 0  1200932522177122304 2019-12-01
# 1  1201226459278385154 2019-12-01
# 2  1201255903498002432 2019-12-01
# 3  1201296419987972096 2019-12-02
# 4  1201303718391615493 2019-12-02
#
#                                                  url  \
# 0  https://twitter.com/JoeBiden/status/1200932522...
# 1  https://twitter.com/JoeBiden/status/1201226459...
# 2  https://twitter.com/JoeBiden/status/1201255903...
# 3  https://twitter.com/JoeBiden/status/1201296419...
# 4  https://twitter.com/JoeBiden/status/1201303718...
#
#                                                tweet  replies  retweets  \
# 0  Eight years of Donald Trump will fundamentally...     4408      7287
# 1  Over the last 30 years, the fight against #HIV...      176       512
# 2  Every voter counts. We need a president who is...     1099      1400
# 3  Congressman and former Admiral @JoeSestak has ...      111       250
# ...

# %% [markdown]
# ### P.O.S. tagging
#
# Part-of-speech tagging marks words in the corpus to a corresponding part of speech tag based on its context and definition.

# %% [markdown]
# Hence, it allows to determine the part of speech (ie. noun, verb, adverb, etc.) for each word.
# POS tags are useful for lemmatization and extracting relationships between words.

# %%
df['pos_tags'] = df['stopwords_removed'].apply(nltk.tag.pos_tag)
df.head()
# Out:
#                     id  timestamp  \
# 0  1200932522177122304 2019-12-01
# 1  1201226459278385154 2019-12-01
# 2  1201255903498002432 2019-12-01
# 3  1201296419987972096 2019-12-02
# 4  1201303718391615493 2019-12-02
#
#                                                  url  \
# 0  https://twitter.com/JoeBiden/status/1200932522...
# 1  https://twitter.com/JoeBiden/status/1201226459...
# 2  https://twitter.com/JoeBiden/status/1201255903...
# 3  https://twitter.com/JoeBiden/status/1201296419...
# 4  https://twitter.com/JoeBiden/status/1201303718...
#
#                                                tweet  replies  retweets  \
# 0  Eight years of Donald Trump will fundamentally...     4408      7287
# 1  Over the last 30 years, the fight against #HIV...      176       512
# 2  Every voter counts. We need a president who is...     1099      1400
# 3  Congressman and former Admiral @JoeSestak has ...      111       250
# ...

# %% [markdown]
# **NLTK’s word lemmatizer** needs the parts of speech tags to be converted to wordnet’s format.
# Write a function which make the proper conversion and then use the function within a list comprehension to apply the conversion.
# Finally, apply NLTK’s word lemmatizer.

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
    
df['wordnet_pos'] = df['pos_tags'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
df.head()
# Out:
#                     id  timestamp  \
# 0  1200932522177122304 2019-12-01
# 1  1201226459278385154 2019-12-01
# 2  1201255903498002432 2019-12-01
# 3  1201296419987972096 2019-12-02
# 4  1201303718391615493 2019-12-02
#
#                                                  url  \
# 0  https://twitter.com/JoeBiden/status/1200932522...
# 1  https://twitter.com/JoeBiden/status/1201226459...
# 2  https://twitter.com/JoeBiden/status/1201255903...
# 3  https://twitter.com/JoeBiden/status/1201296419...
# 4  https://twitter.com/JoeBiden/status/1201303718...
#
#                                                tweet  replies  retweets  \
# 0  Eight years of Donald Trump will fundamentally...     4408      7287
# 1  Over the last 30 years, the fight against #HIV...      176       512
# 2  Every voter counts. We need a president who is...     1099      1400
# 3  Congressman and former Admiral @JoeSestak has ...      111       250
# ...

# %% [markdown]
# ### Information retrieval
# _Named Entity Recognition_ (NER)
#
# NER seeks to extract a real-world entity from the text and sorts into predefined categories such as names of people, organizations, locations and so on.

# %%
df['ne_chunked'] = df['pos_tags'].apply(nltk.ne_chunk)

# %%
named_entities = []

for tagged_tree in df['ne_chunked']: 
    if hasattr(tagged_tree, 'label'):
        entity_name = " ".join(c[0] for c in tagged_tree.leaves())
        entity_type = tagged_tree.label()
        named_entities.append((entity_name, entity_type))

# %%
#check one row
df.ne_chunked[6]
# Out:
# Tree('S', [Tree('GPE', [('American', 'JJ')]), ('leadership', 'NN'), ('served', 'VBD'), ('backbone', 'NN'), Tree('ORGANIZATION', [('NATO', 'NNP')]), ('since', 'IN'), ('founding', 'VBG'), ('70', 'CD'), ('years', 'NNS'), ('ago', 'RB'), ('—', 'NNP'), ('President', 'NNP'), ('Trump.', 'NNP'), ('abdication', 'NN'), ('America’s', 'NNP'), ('traditional', 'JJ'), ('leadership', 'NN'), ('role', 'NN'), ('could', 'MD'), ('come', 'VB'), ('critical', 'JJ'), ('moment', 'NN'), ('alliance.', 'NN'), ('https://t.co/xDIRFzjyBe', 'NN')])

# %%
df.ne_chunked[6][:]
# Out:
# [Tree('GPE', [('American', 'JJ')]),
#  ('leadership', 'NN'),
#  ('served', 'VBD'),
#  ('backbone', 'NN'),
#  Tree('ORGANIZATION', [('NATO', 'NNP')]),
#  ('since', 'IN'),
#  ('founding', 'VBG'),
#  ('70', 'CD'),
#  ('years', 'NNS'),
#  ('ago', 'RB'),
#  ('—', 'NNP'),
#  ('President', 'NNP'),
#  ('Trump.', 'NNP'),
#  ('abdication', 'NN'),
#  ('America’s', 'NNP'),
#  ('traditional', 'JJ'),
#  ('leadership', 'NN'),
#  ('role', 'NN'),
#  ('could', 'MD'),
#  ('come', 'VB'),
#  ('critical', 'JJ'),
#  ('moment', 'NN'),
#  ('alliance.', 'NN'),
#  ('https://t.co/xDIRFzjyBe', 'NN')]

# %% [markdown]
# ### N-grams analysis function
#
# N-grams are set of _n_ words that occurs _in that order_ within a text.
# They caputre the language structure from all the statistical point of view, as in what letter or word is likely to follow the given one.
#
# The function `text_ngrams` allows to create these.
# Data visualization (Section 4) displays N-grams analysis.

# %%
def text_ngrams(corpus, n, g):
    vec = CountVectorizer(ngram_range=(g, g)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %% [markdown]
# ---------------------------------------

# %% [markdown]
# # 3) Sentiment Analysis
#
# Supervised sentiment analysis based on the use of a vocabulary in which words are rated in terms of emotional "scores".

# %% [markdown]
# ### NRClex

# %%
filepath = "/Users/elenazordan/Desktop/corsi ds/CMHB/project_ALL/project/data/NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt"
emolex_df = pd.read_csv(filepath,  names=["word", "emotion", "association"], skiprows=45, sep='\t')
emolex_df.head()
# Out:
#           word   emotion  association
# 0  abandonment  negative            1
# 1  abandonment  positive            0
# 2  abandonment   sadness            1
# 3  abandonment  surprise            1
# 4  abandonment     trust            0

# %%
# what emotions are covered and count values for each 
emolex_df.emotion.unique()
emolex_df.emotion.value_counts()
# Out:
# positive        14178
# negative        14178
# surprise        14178
# trust           14178
# sadness         14178
# anger           14177
# anticipation    14177
# disgust         14177
# fear            14177
# joy             14177
# Name: emotion, dtype: int64

# %%
# how many actual words each emotions has
emolex_df[emolex_df.association == 1].emotion.value_counts()
# Out:
# negative        3322
# positive        2312
# fear            1473
# anger           1245
# trust           1230
# sadness         1189
# disgust         1058
# anticipation     839
# joy              689
# surprise         534
# Name: emotion, dtype: int64

# %%
sid = SentimentIntensityAnalyzer()

# %%
df['scores'] = df['lemmatization'].apply(lambda review: sid.polarity_scores(review))

df['compound']  = df['scores'].apply(lambda score_dict: score_dict['compound'])

df['Negative']  = df['scores'].apply(lambda score_dict: score_dict['neg'])

df['Neutral']  = df['scores'].apply(lambda score_dict: score_dict['neu'])

df['Positive']  = df['scores'].apply(lambda score_dict: score_dict['pos'])



df['number_of_words'] = df['text_string'].str.split().apply(lambda x: len(x))


df.head()
# Out:
#                     id  timestamp  \
# 0  1200932522177122304 2019-12-01
# 1  1201226459278385154 2019-12-01
# 2  1201255903498002432 2019-12-01
# 3  1201296419987972096 2019-12-02
# 4  1201303718391615493 2019-12-02
#
#                                                  url  \
# 0  https://twitter.com/JoeBiden/status/1200932522...
# 1  https://twitter.com/JoeBiden/status/1201226459...
# 2  https://twitter.com/JoeBiden/status/1201255903...
# 3  https://twitter.com/JoeBiden/status/1201296419...
# 4  https://twitter.com/JoeBiden/status/1201303718...
#
#                                                tweet  replies  retweets  \
# 0  Eight years of Donald Trump will fundamentally...     4408      7287
# 1  Over the last 30 years, the fight against #HIV...      176       512
# 2  Every voter counts. We need a president who is...     1099      1400
# 3  Congressman and former Admiral @JoeSestak has ...      111       250
# ...

# %% [markdown]
# **NRClex** Includes now all 9 emotions (fear, anger, anticipation, trust, surprise, positive, negative, sadness, disgust, joy)

# %%
def Review_emo(word):
    """
    Function to convert the raw data to utf-8 formate 
    * convert to data Frame
    
    """
    
    word = str([cell.encode('utf-8') for cell in word]) #convert the text into utf-8 unicode
    str_text = NRCLex(word) 
    str_text = str_text.raw_emotion_scores
    str_text = pd.DataFrame(str_text,index=[0])
    str_text = pd.melt(str_text)
    str_text.columns = ('Emotions','Count')
    str_text = str_text.sort_values('Count')
    
    return str_text


rating_clean = Review_emo(df['lemmatization'])

# %%
rating_clean['percentage'] = rating_clean['Count'].apply(lambda x: round((x/(sum(rating_clean.Count))*100),2))

# %%
rating_clean
# Out:
#        Emotions  Count  percentage
# 8       disgust    835        3.03
# 7      surprise   1207        4.39
# 9       sadness   1790        6.50
# 6           joy   2056        7.47
# 3         anger   2100        7.63
# 4          fear   2327        8.45
# 1  anticipation   2950       10.72
# 5      negative   3681       13.37
# 0         trust   4368       15.87
# 2      positive   6210       22.56

# %% [markdown]
# ---------------------------------------
#
# ## Divide the analysis by time periods
#
# In order to provide useful insights with respect to the approach adopted by Biden towards the pandemic, dataset is split into three time periods according to the evolution of the pandemic:
#
# * TIME PERIOD 1: December 2019 - March 2020
# * TIME PERIOD 2: April 2020 - August 2020
# * TIME PERIOD 3: September 2020 - November 2020

# %%
df_1 = df[df.timestamp < '2020-04-01'].reset_index(drop=True)
df_2 = df[(df.timestamp >= '2020-04-01') & (df.timestamp < '2020-09-01')].reset_index(drop=True)
df_3 = df[df.timestamp >= '2020-09-01'].reset_index(drop=True)

# %%
df_1.shape # (1000, 22)
df_2.shape #(1300, 22)
df_3.shape #(826, 22)
# Out:
# (826, 22)

# %%
rating_clean_1 = Review_emo(df_1['lemmatization'])
rating_clean_1['percentage'] = rating_clean_1['Count'].apply(lambda x: round((x/(sum(rating_clean_1.Count))*100),2))
rating_clean_2 = Review_emo(df_2['lemmatization'])
rating_clean_2['percentage'] = rating_clean_2['Count'].apply(lambda x: round((x/(sum(rating_clean_2.Count))*100),2))
rating_clean_3 = Review_emo(df_3['lemmatization'])
rating_clean_3['percentage'] = rating_clean_3['Count'].apply(lambda x: round((x/(sum(rating_clean_3.Count))*100),2))

# %%
rating_clean_1
# Out:
#        Emotions  Count  percentage
# 8       disgust    292        3.10
# 7      surprise    409        4.34
# 9       sadness    577        6.12
# 6           joy    652        6.91
# 3         anger    804        8.53
# 4          fear    869        9.21
# 1  anticipation   1025       10.87
# 5      negative   1264       13.40
# 0         trust   1466       15.54
# 2      positive   2073       21.98

# %%
rating_clean_2
# Out:
#        Emotions  Count  percentage
# 9       disgust    362        3.14
# 4      surprise    450        3.91
# 7       sadness    752        6.53
# 8         anger    811        7.04
# 3           joy    870        7.56
# 5          fear   1000        8.69
# 2  anticipation   1156       10.04
# 6      negative   1586       13.78
# 1         trust   1812       15.74
# 0      positive   2713       23.57

# %%
rating_clean_3
# Out:
#        Emotions  Count  percentage
# 9       disgust    181        2.75
# 3      surprise    348        5.29
# 6          fear    458        6.96
# 8       sadness    461        7.01
# 5         anger    485        7.37
# 2           joy    534        8.11
# 1  anticipation    769       11.69
# 7      negative    831       12.63
# 4         trust   1090       16.56
# 0      positive   1424       21.64

# %% [markdown]
# ##### Most frequent words

# %%
for text in df_1['text_string'].values:
    for word in text.split():
        count[word] = count[word] + 1
        
count.most_common(20)
# Out:
# [('Trump', 867),
#  ('Donald', 843),
#  ('need', 581),
#  ('get', 431),
#  ('American', 416),
#  ('make', 382),
#  ('one', 352),
#  ('us', 342),
#  ('president', 328),
#  ('President', 308),
#  ('people', 303),
#  ('every', 296),
#  ('take', 267),
#  ('time', 262),
#  ('country', 253),
#  ('help', 253),
#  ('health', 251),
#  ('nation', 244),
#  ('day', 240),
#  ("I'm", 230)]

# %%
for text in df_2['text_string'].values:
    for word in text.split():
        count[word] = count[word] + 1
        
count.most_common(20)
# Out:
# [('Trump', 1173),
#  ('Donald', 1121),
#  ('need', 756),
#  ('American', 567),
#  ('get', 565),
#  ('make', 486),
#  ('one', 465),
#  ('us', 463),
#  ('president', 426),
#  ('people', 422),
#  ('President', 418),
#  ('every', 392),
#  ('nation', 347),
#  ('time', 344),
#  ('take', 341),
#  ('health', 338),
#  ('country', 322),
#  ('help', 318),
#  ('day', 304),
#  ('care', 303)]

# %%
for text in df_3['text_string'].values:
    for word in text.split():
        count[word] = count[word] + 1
        
count.most_common(20)
# Out:
# [('Trump', 1334),
#  ('Donald', 1234),
#  ('need', 810),
#  ('get', 634),
#  ('American', 632),
#  ('make', 560),
#  ('us', 518),
#  ('President', 516),
#  ('one', 514),
#  ('president', 482),
#  ('people', 474),
#  ('every', 446),
#  ('time', 382),
#  ('nation', 376),
#  ('country', 370),
#  ('health', 370),
#  ('take', 366),
#  ('help', 360),
#  ('day', 360),
#  ('care', 336)]

# %% [markdown]
# The previous outputs show that Biden tended to use the same words with similar frequency over months.
# Moreover, in none of them coronavirus' strictly related words appeared, even though "health" and "take care" are always present.
#
# Hence, the function `find_covid_words`allows to retrieve those words and count them.

# %%
def find_covid_words(d):
    l = []
    cont = 0
    for k in d:
        if k.lower().startswith('covi') or k.lower().startswith('coron') or k.lower().startswith('virus'):
            l.append((k, d[k], cont))
            cont += d[k]
        
        
    return l
        
find_covid_words(count)
# Out:
# [('coronavirus.', 24, 0),
#  ('virus', 94, 24),
#  ('coronavirus', 72, 118),
#  ('virus.', 40, 190),
#  ('corona', 2, 230),
#  ('COVID-19:', 6, 232),
#  ('COVID-19', 206, 238),
#  ('coronavirus,', 8, 444),
#  ('Coronavirus', 6, 452),
#  ('COVID-19.', 68, 458),
#  ('COVID-19,', 52, 526),
#  ('COVID-19—and', 2, 578),
#  ('coronaviruses”', 2, 580),
#  ('COVID', 24, 582),
#  ('virus,', 8, 606),
#  ('virus:', 2, 614),
#  ('COVID.', 6, 616),
#  ('COVID,', 2, 622)]

# %% [markdown]
# As expected, the total number of words related to the pandemic is equal to **1645**, hence it would be the second or third most frequent word in Biden's tweets.

# %% [markdown]
# ---------------------------------------
#
# # 4) Data Visualisation

# %% [markdown]
# ##### Barplot: Top 20 frequent words in Biden's tweets

# %%
freq_word = count.most_common(20)

freq_word_plot1 = pd.Series( (v[0] for v in freq_word) )
freq_word_plot2 = pd.Series( (v[1] for v in freq_word) )


data_freq = pd.DataFrame({'Words':freq_word_plot1,'Count':freq_word_plot2})
data_freq = data_freq.sort_values('Count')


#plot
plt.figure(figsize = (12,6))
sns.set_style('darkgrid')
sns.set_context(context='notebook',font_scale=1.5)
sns.barplot(data=data_freq,y='Words',x='Count', palette='Spectral_r');
plt.title("Top 20 Frequent words in Biden's tweets");
plt.tight_layout();

# %% [markdown]
# ##### Wordcloud

# %%
comment_words = '' 
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in df['lemmatization']: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
     
    # Converts each token into lowercase 
    for i in range(len(tokens)):
        if not tokens[i].startswith('https'):
            tokens[i] = tokens[i].lower() 
      
    comment_words += " ".join(tokens)+" "
  


mask = np.array(Image.open('twitterlogo.webp'))


wc = WordCloud(width = 2000, height = 1500, 
                background_color ='white', 
                stopwords = stopwords,
                mask=mask,
                colormap='crest',
                min_font_size = 7).generate(comment_words) 


default_colors = wc.to_array()
  

#plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = '#FFFFFF') 
plt.imshow(wc) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# #### Unigram

# %%
plt.figure(figsize = (10,6))
sns.set_style('darkgrid')
sns.set_context(context='notebook',font_scale=1.5)
Unigram_word = text_ngrams(df.lemmatization,10,1)
Unigram_word = dict(Unigram_word)
sns.barplot(x=list(Unigram_word.values()),y=list(Unigram_word.keys()),palette = 'mako')
plt.title('Unigram Analysis')

plt.show()

# %% [markdown]
# #### Bigram

# %%
plt.figure(figsize = (10,6))
sns.set_style('darkgrid')
sns.set_context(context='notebook',font_scale=1.5)
Unigram_word = text_ngrams(df.lemmatization,10,2)
Unigram_word = dict(Unigram_word)
sns.barplot(x=list(Unigram_word.values()),y=list(Unigram_word.keys()),palette = 'mako')
plt.title('Bigram Analysis')

plt.show()

# %% [markdown]
# #### Trigram

# %%
plt.figure(figsize = (10,6))
sns.set_style('darkgrid')
sns.set_context(context='notebook',font_scale=1.5)
Unigram_word = text_ngrams(df.lemmatization,10,3)
Unigram_word = dict(Unigram_word)
sns.barplot(x=list(Unigram_word.values()),y=list(Unigram_word.keys()),palette = 'mako')
plt.title('Trigram Analysis')

plt.show()

# %% [markdown]
# The n-grams confirm that the main topic of Biden's tweet is the former USA president.
# However, the Bigram analysis highlights the words "covid 19".

# %% [markdown]
# ### Sentiment Analysis visualization

# %%
# data for plot
df_sen = df[['Negative','Neutral', 'Positive']]
df_sen_avg = df_sen.mean().reset_index()
df_sen_avg.columns = ['sentiments','score']

# %%
# data for plot (different time periods)
df_sen_1 = df_1[['Negative','Neutral', 'Positive']]
df_sen_avg_1 = df_sen_1.mean().reset_index()
df_sen_avg_1.columns = ['sentiments','score']

df_sen_2 = df_2[['Negative','Neutral', 'Positive']]
df_sen_avg_2 = df_sen_2.mean().reset_index()
df_sen_avg_2.columns = ['sentiments','score']

df_sen_3 = df_3[['Negative','Neutral', 'Positive']]
df_sen_avg_3 = df_sen_3.mean().reset_index()
df_sen_avg_3.columns = ['sentiments','score']

# %% [markdown]
# ##### Barplot: negative, neutral and positive tweets

# %%
plt.figure(figsize=(10,6))
sns.set_style('darkgrid')
sns.set_context(context='notebook',font_scale=1.5)
sns.barplot(y='score', x='sentiments', data=df_sen_avg, palette='vlag')
plt.title("Sentiments in Bidens' Tweets")
plt.show()

# %% [markdown]
# ##### Divided by time periods

# %%
f, axs = plt.subplots(1, 3, figsize=(17, 7))

sns.set_style('darkgrid')

sns.set_context(context='notebook',font_scale=1.5)


sns.barplot(y='score', x='sentiments', data=df_sen_avg_1, palette='vlag',ax=axs[0])
axs[0].set(xlabel="time perdiod 1", ylabel = "")

sns.barplot(y='score', x='sentiments', data=df_sen_avg_2, palette='vlag',ax=axs[1])
axs[1].set(xlabel="time perdiod 2", ylabel = "")

sns.barplot(y='score', x='sentiments', data=df_sen_avg_3, palette='vlag',ax=axs[2])
axs[2].set(xlabel="time perdiod 3", ylabel = "")


f.text(0.5, 0, 'Sentiments', ha='center')
f.text(0.05, 0.5, 'Score', va='center', rotation='vertical')


f.suptitle("Sentiments in Bidens' Tweets")

plt.show()

# %% [markdown]
# Overall, Joe Biden's tweets were almost classified as neutral.
# Despite the number of the positive ones is much smaller, it is always greater than those classified as negative.
#
# * * *

# %% [markdown]
# ##### Barplot: emotional affects in tweets
#
# Visualization of the emotional affects (fear, anger, anticipation, trust, surprise, positive, negative, sadness, disgust, joy)

# %%
plt.figure(figsize=(10,6))
sns.set_style('darkgrid')
sns.set_context(context='notebook',font_scale=1.5)
sns.barplot(y='Emotions',x='percentage',data=rating_clean, palette="rocket")
plt.xlabel("Sentiment score %")

plt.title("Emotional affects in Biden's Tweets")
plt.show()

# %% [markdown]
# ##### Divided by time periods

# %%
f, axs = plt.subplots(1, 3, figsize=(25, 7))

#sns.set(xlim=(0,2600))

sns.set_style('darkgrid')

sns.barplot(y='Emotions',x='percentage',data=rating_clean_1, palette="rocket",ax=axs[0])
axs[0].set(xlabel="", ylabel="")
axs[0].set_xlim([0, 30])

sns.barplot(y='Emotions',x='percentage',data=rating_clean_2, palette="rocket", ax=axs[1])
axs[1].set(xlabel="",ylabel="")
axs[1].set_xlim([0, 30])

sns.barplot(y='Emotions',x='percentage',data=rating_clean_3, palette="rocket", ax=axs[2])
axs[2].set(xlabel="",ylabel="")
axs[2].set_xlim([0, 30])

f.text(0.5, 0, 'Sentiment score %', ha='center', fontsize='large')
f.text(0.05, 0.5, 'Sentiments', va='center', rotation='vertical', fontsize='large')


f.suptitle("Emotional affects in Biden's Tweets over months of 2020", fontsize='x-large', va='top')
plt.show()

# %% [markdown]
# These last visualizations confirm that strictly positive sentiments are more that strictly negative ones.
# However, while disgust is always the ones with lowest values, other emotions change their position, such as _joy_, which increased significantly over months.
